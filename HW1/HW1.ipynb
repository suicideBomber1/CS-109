# %% [markdown]
# # Homework 1. Exploratory Data Analysis
#
# Due: Thursday, September 18, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW1.ipynb download=HW1.ipynb> Download this assignment</a>
#
# ---

# %% [markdown]
# ## Introduction
#
# In this homework we ask you three questions that we expect you to answer using data. For each question we ask you to complete a series of tasks that should help guide you through the data analysis. Complete these tasks and then write a short (100 words or less) answer to the question.
#
# **Note**: We will briefly discuss this homework assignment on Thursday in class.
#
# #### Data
# For this assignment we will use two databases:
#
# 1. The [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics) which contains the "complete batting and pitching statistics from 1871 to 2013, plus fielding statistics, standings, team stats, managerial records, post-season data, and more. For more details on the latest release, please [read the documentation](http://seanlahman.com/files/database/readme2012.txt)."
#
# 2. [Gapminder](http://www.gapminder.org) is a great resource that contains over [500 data sets](http://www.gapminder.org/data/) related to world indicators such as income, GDP and life expectancy.
#
#
# #### Purpose
#
# In this assignment, you will learn how to:
#
# a. Load in CSV files from the web.
#
# b. Create functions in python.
#
# C. Create plots and summary statistics for exploratory data analysis such as histograms, boxplots and scatter plots.
#
#
# #### Useful libraries for this assignment
#
# * [numpy](http://docs.scipy.org/doc/numpy-dev/user/index.html), for arrays
# * [pandas](http://pandas.pydata.org/), for data frames
# * [matplotlib](http://matplotlib.org/), for plotting
#
# ---

# %%
! pip install --user matplotlib

# %%
! python --version
# Out:
# Python 3.6.1 :: Anaconda 4.4.0 (x86_64)

# %%
! source activate root

# %%
import sys
sys.executable
# sys.path
# Out:
# '/Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6'

# %%
import io

# %%
! /Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install matplotlib
# Out:
# ...
#     100% |████████████████████████████████| 13.2MB 47kB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 1.2MB/s ta 0:00:01
# ...

# %%
# special IPython command to prepare the notebook for matplotlib
% matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Problem 1
#
# In Lecture 1, we showed a plot that provided evidence that the 2002 and 2003 Oakland A's, a team that used data science, had a competitive advantage. Since, others teams have started using data science as well. Use exploratory data analysis to determine if the competitive advantage has since disappeared.

# %% [markdown]
# #### Problem 1(a)
# Load in [these CSV files](http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip) from the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics). For this assignment, we will use the 'Salaries.csv' and 'Teams.csv' tables. Read these tables into a pandas `DataFrame` and show the head of each table.
#
# **Hint** Use the [requests](http://docs.python-requests.org/en/latest/), [StringIO](http://docs.python.org/2/library/stringio.html) and [zipfile](https://docs.python.org/2/library/zipfile.html) modules to get from the web.

# %%
import requests
from io import StringIO
import zipfile

r = requests.get('http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip')

# %%
import io 
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()
# Out:
# <zipfile.ZipFile file=<_io.BytesIO object at 0x11780d518> mode='r'>

# %%
# Loading Salaries.csv and Teams.csv

salaries = pd.read_csv('Salaries.csv', delimiter=',')
teams = pd.read_csv('Teams.csv', delimiter=',')

# %% [markdown]
# #### Problem 1(b)
#
# Summarize the Salaries DataFrame to show the total salaries for each team for each year. Show the head of the new summarized DataFrame.

# %%
TotalSalaries = salaries.groupby(['yearID', 'teamID'], as_index=False).sum()
TotalSalaries.head()
# Out:
#    yearID teamID    salary
# 0    1985    ATL  14807000
# 1    1985    BAL  11560712
# 2    1985    BOS  10897560
# 3    1985    CAL  14427894
# 4    1985    CHA   9846178

# %%
TotalSalaries.dtypes
# Out:
# yearID     int64
# teamID    object
# salary     int64
# dtype: object

# %%
import pandas as pd

salaries = pd.read_csv('./lahman-csv_2014-02-14/salaries.csv')
salaries.head()
# Out:
#    yearID teamID lgID   playerID   salary
# 0    1985    BAL   AL  murraed02  1472819
# 1    1985    BAL   AL   lynnfr01  1090000
# 2    1985    BAL   AL  ripkeca01   800000
# 3    1985    BAL   AL   lacyle01   725000
# 4    1985    BAL   AL  flanami01   641667

# %%
teams = pd.read_csv('./lahman-csv_2014-02-14/Teams.csv')[['yearID', 'teamID', 'W']]
teams.head()
# Out:
#    yearID teamID   W
# 0    1871    PH1  21
# 1    1871    CH1  19
# 2    1871    BS1  20
# 3    1871    WS3  15
# 4    1871    NY2  16

# %%
TotSalaries = salaries.groupby(['yearID', 'teamID'], as_index=False).sum()
TotSalaries.head()
# Out:
#    yearID teamID    salary
# 0    1985    ATL  14807000
# 1    1985    BAL  11560712
# 2    1985    BOS  10897560
# 3    1985    CAL  14427894
# 4    1985    CHA   9846178

# %%
TotSalaries.dtypes
# Out:
# yearID     int64
# teamID    object
# salary     int64
# dtype: object

# %% [markdown]
# #### Problem 1(c)
#
# Merge the new summarized Salaries DataFrame and Teams DataFrame together to create a new DataFrame
# showing wins and total salaries for each team for each year year. Show the head of the new merged DataFrame.
#
# **Hint**: Merge the DataFrames using `teamID` and `yearID`.

# %%
# teams.head()
teams = teams[['yearID', 'teamID', 'W']]
teams.head()
# Out:
#    yearID teamID   W
# 0    1871    PH1  21
# 1    1871    CH1  19
# 2    1871    BS1  20
# 3    1871    WS3  15
# 4    1871    NY2  16

# %%
merged_df = pd.merge(TotalSalaries, teams, on=['yearID', 'teamID'])
merged_df.head()
# Out:
#    yearID teamID    salary   W
# 0    1985    ATL  14807000  66
# 1    1985    BAL  11560712  83
# 2    1985    BOS  10897560  81
# 3    1985    CAL  14427894  90
# 4    1985    CHA   9846178  85

# %%
#your code here
merged_df = pd.merge(TotSalaries, teams, on=['yearID', 'teamID'], how='inner')
merged_df.head()
# Out:
#    yearID teamID    salary   W
# 0    1985    ATL  14807000  66
# 1    1985    BAL  11560712  83
# 2    1985    BOS  10897560  81
# 3    1985    CAL  14427894  90
# 4    1985    CHA   9846178  85

# %% [markdown]
# #### Problem 1(d)
#
# How would you graphically display the relationship between total wins and total salaries for a given year? What kind of plot would be best? Choose a plot to show this relationship and specifically annotate the Oakland baseball team on the on the plot. Show this plot across multiple years. In which years can you detect a competitive advantage from the Oakland baseball team of using data science? When did this end?
#
# **Hints**: Use a `for` loop to consider multiple years. Use the `teamID` (three letter representation of the team name) to save space on the plot.

# %%
import seaborn as sns
sns.set_context('talk')
sns.set_style('whitegrid')

# %%
merged_df.head()
# Out:
#    yearID teamID    salary   W
# 0    1985    ATL  14807000  66
# 1    1985    BAL  11560712  83
# 2    1985    BOS  10897560  81
# 3    1985    CAL  14427894  90
# 4    1985    CHA   9846178  85

# %%
df.head()
# Out:
#      yearID teamID     salary   W
# 798    2013    ARI   90132000  81
# 799    2013    ATL   87871525  96
# 800    2013    BAL   84393333  85
# 801    2013    BOS  151530000  97
# 802    2013    CHA  120065277  63

# %%
years = np.array(merged_df['yearID'])
years = np.unique(years)

for year in years:
    df = merged_df[merged_df.yearID==year]
    plt.scatter(df.salary/1e6, df.W)
    plt.xlabel('Salary per year (in millions)')
    plt.ylabel('Wins')
    plt.title("Wins vs Salary for year: "+ str(year))
    plt.annotate('OAK', xy= (df[df.teamID=='OAK']['salary']/1e6, df[df.teamID=='OAK']['W']),
                 xytext=(10, 70), textcoords='offset points', ha='right', va='bottom',
                 bbox= dict(boxstyle='round, pad=0.5', fc='yellow', alpha=0.6),
                arrowprops = dict(arrowstyle = '->', facecolor = 'black' , connectionstyle = 'arc3,rad=0'))
    plt.show()

# %%
TeamsName = pd.read_csv('./lahman-csv_2014-02-14/Teams.csv')[['teamID', 'name']]
TeamsName[TeamsName.teamID == 'OAK ']
# Out:
# Empty DataFrame
# Columns: [teamID, name]
# Index: []

# %%
#your code here
# All the years in the data
years = np.unique(np.array(merged_df.yearID))
teamName= 'OAK'
for year in years:
    df = merged_df[merged_df.yearID == year]
    plt.scatter(df.salary/1e6, df.W)
    plt.xlim
    plt.ylabel('Wins')
    plt.xlabel('Salary per year (in millions)')
    plt.title('Wins vs Salary for year ' + str(year))
    plt.annotate('OAK', xy=(df['salary'][df.teamID=='OAK']/1e6, df['W'][df.teamID=='OAK']),
    xytext = (-30, -20), textcoords='offset points', ha = 'right', va = 'bottom',
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.6),
            arrowprops = dict(arrowstyle = '->', facecolor = 'black' , connectionstyle = 'arc3,rad=0'))
    plt.show()

# %% [markdown]
# #### Problem 1(e):
#
# **For AC209 Students**: Fit a linear regression to the data from each year and obtain the residuals. Plot the residuals against time to detect patterns that support your answer in 1(d).

# %%
from sklearn.linear_model import LinearRegression

merged_df.head(), years
year = 1985
wins = np.array(merged_df[merged_df.yearID == year]['W']).reshape(-1, 1)
salary = np.array(merged_df[merged_df.yearID == year]['salary']).reshape(-1, 1)

wins_train = wins[:-10]
wins_test = wins [-10:]

salary_train = salary[:-10]
salary_test = salary[-10:]

model = LinearRegression()
model.fit(salary_train, wins_train)

wins_pred = model.predict(salary_test)
plt.scatter(salary_test, wins_test)
plt.plot(salary_test, wins_pred, linewidth=3, color='blue')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/linalg/basic.py:1018: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 2
#
# Several media reports have demonstrated the income inequality has increased in the US during this last decade. Here we will look at global data. Use exploratory data analysis to determine if the gap between Africa/Latin America/Asia and Europe/NorthAmerica has increased, decreased or stayed the same during the last two decades.

# %% [markdown]
# #### Problem 2(a)
#
# Using the list of countries by continent from [World Atlas](http://www.worldatlas.com/cntycont.htm) data, load in the `countries.csv` file into a pandas DataFrame and name this data set as `countries`.  This data set can be found on Github in the 2014_data repository [here](https://github.com/cs109/2014_data/blob/master/countries.csv).

# %%
import requests
import io
import pandas as pd

url = 'https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'
r = requests.get(url).content
e = io.BytesIO(r)
df = pd.read_csv(e)
df.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %%
#your code here
import io
import requests

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"

d = requests.get(url).content
s = io.BytesIO(d)
countries = pd.read_csv(s)
countries.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# Using the [data available on Gapminder](http://www.gapminder.org/data/), load in the [Income per person (GDP/capita, PPP$ inflation-adjusted)](https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0) as a pandas DataFrame and name this data set as `income`.
#
# **Hint**: Consider using the pandas function `pandas.read_excel()` to read in the .xlsx file directly.

# %%
url = 'https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0'
r = requests.get(url).content
d = io.BytesIO(r)
data = pd.read_excel(d, sheetname='Data')
data.head()
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-138-88cc8026dd3b> in <module>()
#       2 r = requests.get(url).content
#       3 d = io.BytesIO(r)
# ----> 4 data = pd.read_excel(d, sheetname='Data')
#       5 data.head()
#
# /Users/Nagarjuna/anaconda/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     198
#     199     if not isinstance(io, ExcelFile):
# --> 200         io = ExcelFile(io, engine=engine)
#     201
#     202     return io._parse_excel(
#
# /Users/Nagarjuna/anaconda/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     253             # N.B. xlrd.Book has a read attribute too
# ...

# %%
#your code here
url = 'https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&output=xls'
d = requests.get(url).content
s = io.BytesIO(d)
data = pd.read_excel(s, sheetname= 'Data')
data.head()

# the file doesnt exist and we get an error while loading it.. SO I have downloaded it locally to make it work.
# Out:
# ---------------------------------------------------------------
# ModuleNotFoundError           Traceback (most recent call last)
# <ipython-input-137-9ba8ebcad566> in <module>()
#       8 income_link = 'https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&output=xls'
#       9 source = io.BytesIO(requests.get(income_link).content)
# ---> 10 income = pd.read_excel(source, sheetname = "Data")
#      11 income.head()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     201
#     202     if not isinstance(io, ExcelFile):
# --> 203         io = ExcelFile(io, engine=engine)
#     204
#     205     return io._parse_excel(
#
# ...

# %%
! /Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install xlrd
# Out:
# ...
#     100% |████████████████████████████████| 112kB 490kB/s ta 0:00:01
# ...

# %%
income = pd.read_excel('./indicator gapminder gdp_per_capita_ppp.xlsx', encoding="ISO-8859-1")
income.head()
income = income.set_index(income.columns[0])
income.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# GDP per capita
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            603.0  603.0  603.0  603.0  603.0  603.0  603.0  603.0
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                667.0  667.0  668.0  668.0  668.0  668.0  668.0  668.0
# Algeria                716.0  716.0  717.0  718.0  719.0  720.0  721.0  722.0
#
#                         1808   1809   ...        2006     2007     2008  \
# GDP per capita                        ...
# Abkhazia                 NaN    NaN   ...         NaN      NaN      NaN
# Afghanistan            603.0  603.0   ...      1173.0   1298.0   1311.0
# Akrotiri and Dhekelia    NaN    NaN   ...         NaN      NaN      NaN
# Albania                668.0  668.0   ...      7476.0   7977.0   8644.0
# Algeria                723.0  724.0   ...     12088.0  12289.0  12314.0
#
# ...

# %%
# Transform the data set to have years as the rows and countries as the columns. 
# Show the head of this data set when it is loaded

income = income.transpose()
income.head()
# Out:
# GDP per capita  Abkhazia  Afghanistan  Akrotiri and Dhekelia  Albania  \
# 1800                 NaN        603.0                    NaN    667.0
# 1801                 NaN        603.0                    NaN    667.0
# 1802                 NaN        603.0                    NaN    668.0
# 1803                 NaN        603.0                    NaN    668.0
# 1804                 NaN        603.0                    NaN    668.0
#
# GDP per capita  Algeria  American Samoa  Andorra  Angola  Anguilla  \
# 1800              716.0             NaN   1197.0   618.0       NaN
# 1801              716.0             NaN   1199.0   620.0       NaN
# 1802              717.0             NaN   1201.0   623.0       NaN
# 1803              718.0             NaN   1204.0   626.0       NaN
# 1804              719.0             NaN   1206.0   628.0       NaN
#
# GDP per capita  Antigua and Barbuda ...   North Yemen (former)  \
# 1800                          757.0 ...                    NaN
# ...

# %%
# Graphically display the distribution of income per person 
# across all countries in the world for any given year (e.g. 2000). What kind of plot would be best?

income_2000 = income[income.index == 2000]
income_2000.dropna(axis=1).values.reshape(203,).shape

plt.hist(income_2000.dropna(axis=1).values.reshape(203,), bins=20, ec='k')
plt.show()

# %%
# Write a function to merge the countries and income data sets for any given year.

df.head()
# Country and Region are the columns in df
# Testing for a particular year
year = 2000
year_income = pd.DataFrame(income.loc[income.index == year].values.transpose(), columns=['Income'])
year_income['Country'] = income.columns
year_income.set_index('Income')

merged_df = pd.merge(year_income, df, on=['Country'])
merged_df.head()
# Out:
#     Income      Country  Region
# 0    962.0  Afghanistan    ASIA
# 1   5305.0      Albania  EUROPE
# 2   9885.0      Algeria  AFRICA
# 3  31662.0      Andorra  EUROPE
# 4   3387.0       Angola  AFRICA

# %%
# Write a function to merge the countries and income data sets for any given year.

def mergeByYear(year):
    year_income = pd.DataFrame(income.loc[income.index == year].values.transpose(), columns=['Income'])
    year_income['Country'] = income.columns
#     year_income.set_index['Income']
    
    merged_df = pd.merge(year_income, df, on=['Country'])
    return merged_df

# %%
mergeByYear(2000)
# Out:
#     Income      Country  Region
# 0    962.0  Afghanistan    ASIA
# 1   5305.0      Albania  EUROPE
# 2   9885.0      Algeria  AFRICA
# 3  31662.0      Andorra  EUROPE
# 4   3387.0       Angola  AFRICA

# %%
import pandas as pd
income = pd.read_excel('./indicator gapminder gdp_per_capita_ppp.xlsx',encoding = "ISO-8859-1")
income = income.set_index(income.columns[0])
income.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# GDP per capita
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            603.0  603.0  603.0  603.0  603.0  603.0  603.0  603.0
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                667.0  667.0  668.0  668.0  668.0  668.0  668.0  668.0
# Algeria                716.0  716.0  717.0  718.0  719.0  720.0  721.0  722.0
#
#                         1808   1809   ...        2006     2007     2008  \
# GDP per capita                        ...
# Abkhazia                 NaN    NaN   ...         NaN      NaN      NaN
# Afghanistan            603.0  603.0   ...      1173.0   1298.0   1311.0
# Akrotiri and Dhekelia    NaN    NaN   ...         NaN      NaN      NaN
# Albania                668.0  668.0   ...      7476.0   7977.0   8644.0
# Algeria                723.0  724.0   ...     12088.0  12289.0  12314.0
#
# ...

# %% [markdown]
# Transform the data set to have years as the rows and countries as the columns. Show the head of this data set when it is loaded.

# %%
#your code here

income = income.transpose()
income.set_index(income.columns[0])
income.head()
# Out:
# GDP per capita  Abkhazia  Afghanistan  Akrotiri and Dhekelia  Albania  \
# 1800                 NaN        603.0                    NaN    667.0
# 1801                 NaN        603.0                    NaN    667.0
# 1802                 NaN        603.0                    NaN    668.0
# 1803                 NaN        603.0                    NaN    668.0
# 1804                 NaN        603.0                    NaN    668.0
#
# GDP per capita  Algeria  American Samoa  Andorra  Angola  Anguilla  \
# 1800              716.0             NaN   1197.0   618.0       NaN
# 1801              716.0             NaN   1199.0   620.0       NaN
# 1802              717.0             NaN   1201.0   623.0       NaN
# 1803              718.0             NaN   1204.0   626.0       NaN
# 1804              719.0             NaN   1206.0   628.0       NaN
#
# GDP per capita  Antigua and Barbuda ...   North Yemen (former)  \
# 1800                          757.0 ...                    NaN
# ...

# %%
# For analysis purposes I took just the last 10 years
import numpy as np
import matplotlib.pyplot as plt
years = np.array(income.index)
last10years = years[-10:]
last10years
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], dtype=object)

# %%
income.loc[income.index == 2000].dropna(axis=1).values.reshape(203,).shape
# Out:
# (203,)

# %% [markdown]
# #### Problem 2(b)
#
# Graphically display the distribution of income per person across all the countries in the world for any given year (e.g 2000). What kind of plot would be the best?

# %%
year = 2000
plt.hist(income.loc[income.index == 2000].dropna(axis=1).values.reshape(203,), bins=20)
plt.xlabel('Income per person')
plt.ylabel('Frequency')
plt.title('Year: {}'.format(year))
plt.show()

# %% [markdown]
# #### Problem 2(c)
#
# Write a function to merge the `countries` and `income` data sets for any given year.

# %%
countries.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# ### For a particular year (say 1800)

# %%
year = 1800
income_year = pd.DataFrame(income.loc[income.index == year].values.transpose(), columns=['Income'])
income_year.head()
income_year['Country'] = income.columns
income_year.head()
# Out:
#    Income                Country
# 0     NaN               Abkhazia
# 1   603.0            Afghanistan
# 2     NaN  Akrotiri and Dhekelia
# 3   667.0                Albania
# 4   716.0                Algeria

# %%
merged_df = pd.merge(countries, income_year, on='Country')
merged_df.head()
# Out:
#     Country  Region  Income
# 0   Algeria  AFRICA   716.0
# 1    Angola  AFRICA   618.0
# 2     Benin  AFRICA   597.0
# 3  Botswana  AFRICA   397.0
# 4   Burundi  AFRICA   418.0

# %%
"""
Function
--------
mergeByYear


Return a merged DataFrame containing the income, 
country name and region for a given year. 

Parameters
----------
year : int
    The year of interest

Returns
-------
a DataFrame
   A pandas DataFrame with three columns titled 
   'Country', 'Region', and 'Income'. 

Example
-------
>>> mergeByYear(2010)
"""
#your code here

# countries.head()
# income.head()
# year = 1800
# income_year = income.loc[income.index == year]
# gdp = income_year.transpose().head()
def mergeByYear(year):
    income_year = pd.DataFrame(income.loc[income.index == year].values.transpose(), columns=['Income'])
    income_year['Country'] = income.columns
#     print("The new dataframe income_year is \n")
#     print(income_year.head())
    merged_df = pd.merge(countries, income_year, on='Country')
    return merged_df

# %%
df = mergeByYear(1800).head()
df
# Out:
#     Country  Region  Income
# 0   Algeria  AFRICA   716.0
# 1    Angola  AFRICA   618.0
# 2     Benin  AFRICA   597.0
# 3  Botswana  AFRICA   397.0
# 4   Burundi  AFRICA   418.0

# %% [raw]
# #### Problem 2(d)
#
# Use exploratory data analysis tools such as histograms and boxplots to explore the distribution of the income per person by region data set from 2(c) for a given year. Describe how these change through the recent years?
#
# **Hint**: Use a `for` loop to consider multiple years.

# %%
!  /Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install seaborn
# Out:
# ...
#     100% |████████████████████████████████| 184kB 1.4MB/s ta 0:00:01
# ...
#   Running setup.py install for seaborn ... done
# ...

# %%
mergeByYear(2001)
last_10_years = years[-10:]
last_10_years
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013])

# %%
merged_df = mergeByYear(2000)
# merged_df['Region']

# %%
# for year in last_10_years:
year = 2000
merged_df = mergeByYear(year)
sns.boxplot(merged_df['Region'], merged_df['Income'])

# %%
# Use exploratory data analysis tools such as histograms and boxplots to explore the distribution 
# of the income per person by region data set from 2(c) for a given year. Describe how these change through the
# recent years?

for year in last_10_years:
    plt.figure(figsize=(12, 6))
    merged_df = mergeByYear(year)
    sns.boxplot(merged_df['Region'], merged_df['Income'])
    plt.yscale('log')
    plt.title('For year: {}'.format(year))
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
merged_df = mergeByYear(2000)
income_df = np.array(merged_df.Income.dropna().values)
plt.hist(income_df, ec='k', bins=30)
plt.xlim(0, 120000)
plt.show()

# %%
for year in last_10_years:
    merged_df = mergeByYear(year)
    income_df = np.array(merged_df['Income'].dropna().values)
    plt.hist(income_df, ec='k', bins=30)
#     plt.xlim(0, 120000)
    plt.xlabel('Income')
    plt.title('Income of various countries for year: {}'.format(year))
    plt.show()

# %%
#your code here
import seaborn as sns
# Plots can be made to look better by seaborn.. Will try to improve the plots in future
for year in last10years:
    df = mergeByYear(year)
    df.boxplot('Income', by='Region') 
    plt.title("For year {}".format(year))
    plt.ylabel("Income per person (log scale)")
    plt.yscale('log')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
for year in last10years:
    df = mergeByYear(year)
    income_arr = np.array(df.Income.dropna().values)
    plt.hist(income_arr, bins=30)
    plt.yscale('linear')
    plt.show()

# %% [markdown]
# ## Discussion for Problem 2
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 3
#
# In general, if group A has larger values than group B on average, does this mean the largest values are from group A? Discuss after completing each of the problems below.

# %% [markdown]
# #### Problem 3(a)
#
# Assume you have two list of numbers, X and Y, with distribution approximately normal. X and Y have standard deviation equal to 1, but the average of X is different from the average of Y.  If the difference in the average of X and the average of Y is larger than 0, how does the proportion of X > a compare to the proportion of Y > a?

# %% [markdown]
# Write a function that analytically calculates the ratio of these two proportions: Pr(X > a)/Pr(Y > a) as function of the difference in the average of X and the average of Y.
#
# **Hint**: Use the `scipy.stats` module for useful functions related to a normal random variable such as the probability density function, cumulative distribution function and survival function.
#
# **Update**: Assume Y is normally distributed with mean equal to 0.

# %% [markdown]
# Show the curve for different values of a (a = 2,3,4 and 5).

# %%
x = np.arange(-5, 5, 0.05)
y = norm(loc=0, scale=1)
plt.plot(x, 1- y.cdf(x))

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

# x = np.arange(-5, 5, 0.05)
# y = norm(loc=0, scale=1)
# plt.plot(x, y.pdf(x))

# Function to calculate the ratio of Pr(X>a)/Pr(Y>a)
# Ratio of normals

def ratioNormals(mean_x, a):
    X = norm(loc=mean_x, scale=1)
    Y = norm(loc=0, scale=1)
    pr_x = 1 - X.cdf(a)
    pr_y = 1 - Y.cdf(a)
    return pr_x/pr_y

# %%
a = [2, 3, 4, 5]
x = np.linspace(0, 5, 51)

plt.figure(figsize=(12, 6))
for choice in a:
    plt.plot(x, ratioNormals(x, choice), label='a: {}'.format(choice))
    plt.yscale('log')
    plt.xlabel('Diff')
    plt.ylabel('Pr(X > a)/Pr(Y > a)')
    plt.title('Ratio of Pr(X > a) and Pr(Y > a) for different values of diff')
    plt.legend()
plt.tight_layout()
plt.show()

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

std = 1
mean_y = 0
# x = norm()
y = norm.cdf(2)
# plt.plot(x)
# plt.show()
y
# Out:
# 0.97724986805182079

# %%
import numpy as np
x = np.linspace(norm.ppf(0.01), norm.ppf(0.99), 200)
norm_dist = norm.pdf(x)
cdf_dist = norm.cdf(x)
plt.plot(x, norm_dist)
plt.plot(x, cdf_dist)
plt.show()

# %%
x = np.linspace(norm.ppf(0.01, loc=1), norm.ppf(0.99, loc=1), 200)
norm_dist = norm.pdf(x, loc=1)
cdf_dist = norm.cdf(x, loc=1)
plt.plot(x, norm_dist)
plt.plot(x, 1-cdf_dist)
plt.show()

# %%
1-norm.cdf(2, loc=1)
# Out:
# 0.15865525393145707

# %%
"""
Function
--------
ratioNormals

Return ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a) as function of 
    the difference in the average of X 
    and the average of Y. 

Parameters
----------
diff : difference in the average of X 
    and the average of
    Y. 
a : cutoff value

Returns
-------
Returns ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a)
    
Example
-------
>>> ratioNormals(diff = 1, a = 2)
"""
#your code here
def ratioNormals(diff, a):
    mean_x = diff
    mean_y = 0
    # Now we check the prob of X>a and Y>a
    # Pr(X>a)
    pr_X = 1 - norm.cdf(a, loc=diff)
    pr_Y = 1 - norm.cdf(a, loc=0)
    return pr_X/pr_Y

# %%
#your code here

diff = np.linspace(0, 5, 51)
a_values = range(1, 6)
plt.figure(figsize=(10, 6))
for a in a_values:
    ratios = np.array(ratioNormals(diff, a))
    plt.plot(diff, ratios, label="a: {}".format(a))
    plt.legend(loc="upper left")

    
plt.xlabel("Diff", fontsize='large')
plt.ylabel("Pr(X > a) / Pr(Y > a)", fontsize='large')
plt.yscale('log')
plt.title("Ratio of Pr(X) and Pr(Y) for different values of Diff", fontsize='large')
plt.legend()
plt.show()

# %% [markdown]
# #### Problem 3(b)
#
# Now consider the distribution of income per person from two regions: Asia and South America. Estimate the average income per person across the countries in those two regions. Which region has the larger average of income per person across the countries in that region?
#
# **Update**: Use the year 2012.

# %%
merged_df = mergeByYear(2012)
# merged_df[merged_df.loc[merged_df.Region == 'Asia']]
asian_income_mean = merged_df[merged_df.Region == 'ASIA']["Income"].mean()
south_american_income_mean = merged_df[merged_df.Region == 'SOUTH AMERICA']['Income'].mean()
asian_income_mean, south_american_income_mean
# Out:
# (23500.432432432433, 13015.75)

# %% [markdown]
# Asia has the higher average income per population than South America

# %%
regions = np.unique(np.array(df.Region))
regions
# Out:
# array(['AFRICA', 'ASIA', 'EUROPE', 'NORTH AMERICA', 'OCEANIA',
#        'SOUTH AMERICA'], dtype=object)

# %%
#your code here
df = mergeByYear(2012)
df.head()
df[df.Region=='SOUTH AMERICA'].Income.mean(), df[df.Region=='ASIA'].Income.mean()
# Out:
# (13015.75, 23500.432432432433)

# %%
# for plotting the results in box plot 
# Asian and South American countries with their incomes per person

new_df = df[(df.Region == 'SOUTH AMERICA') | (df.Region == 'ASIA')]
new_df.boxplot('Income', by='Region')
plt.yscale('log')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# #### Problem 3(c)
#
# Calculate the proportion of countries with income per person that is greater than 10,000 dollars. Which region has a larger proportion of countries with income per person greater than 10,000 dollars? If the answer here is different from the answer in 3(b), explain why in light of your answer to 3(a).
#
# **Update**: Use the year 2012.

# %%
regions = np.unique(merged_df['Region'])

# %%
# merged_df[merged_df.Region == 'AFRICA']['Country'].count()

countries_per_region = {}
for region in regions:
    countries_per_region[region] = (merged_df[merged_df.Region == region]['Country'].count())

countries_per_region
# Out:
# {'AFRICA': 50,
#  'ASIA': 37,
#  'EUROPE': 44,
#  'NORTH AMERICA': 20,
#  'OCEANIA': 13,
#  'SOUTH AMERICA': 12}

# %%
higher_income_per_region = {}
merged_df = mergeByYear(2012)
merged_df.head()
for region in regions:
    higher_income_per_region[region] = (merged_df[(merged_df.Income > 10000) & (merged_df.Region == region)]['Income'].count())

higher_income_per_region
# Out:
# {'AFRICA': 10,
#  'ASIA': 21,
#  'EUROPE': 37,
#  'NORTH AMERICA': 13,
#  'OCEANIA': 4,
#  'SOUTH AMERICA': 9}

# %%
higher_income = merged_df[merged_df.Income > 10000]
region_wise_higher_income = higher_income.groupby(['Region'])
region_wise_higher_income.describe()

dataFrame = pd.DataFrame()
dataFrame['Region'] = regions
dataFrame['Total # countries'] = countries_per_region.values()
dataFrame['# countries having per capita greater than $10,000'] = higher_income_per_region.values()
dataFrame['Ratio'] = dataFrame['# countries having per capita greater than $10,000'] / dataFrame['Total # countries']
dataFrame
# Out:
#           Region  Total # countries  \
# 0         AFRICA                 50
# 1           ASIA                 37
# 2         EUROPE                 44
# 3  NORTH AMERICA                 20
# 4        OCEANIA                 13
# 5  SOUTH AMERICA                 12
#
#    # countries having per capita greater than $10,000     Ratio
# 0                                                 10   0.200000
# 1                                                 21   0.567568
# 2                                                 37   0.840909
# 3                                                 13   0.650000
# 4                                                  4   0.307692
# 5                                                  9   0.750000

# %%
sns.barplot(dataFrame['Region'], dataFrame['Ratio'])
plt.ylabel('Ratio')
plt.xlabel('Region')
plt.show()

# %%
higher_income_per_region = []

for region in regions:
    print(region)
    higher_income_per_region.append(len(region_wise_higher_income.groups[str(region)]))
higher_income_per_region
# Out:
# AFRICA
# ASIA
# EUROPE
# NORTH AMERICA
# OCEANIA
# SOUTH AMERICA
# [10, 21, 37, 13, 4, 9]

# %%
# df.head()

no_of_countries_region = []
for continent in regions:
    no_of_countries_region.append(len(df[df.Region == continent]))

no_of_countries_region
# Out:
# [50, 37, 44, 20, 13, 12]

# %%
#your code here
higher_income = df[df.Income > 10000]

# Number of countries that have a per capita income of greater than $10,000
len(higher_income)  # 94 for year 2012

# Number of countries that have income greater than $10,000 region-wise
region_wise_higher_income = higher_income.groupby(['Region'])
region_wise_higher_income.describe(), len(region_wise_higher_income.groups['AFRICA'])

# dataframe = pd.DataFrame(regions, no_of_countries_region, higher_income_per_region, columns=['a', 'b', 'c'])
dataframe = pd.DataFrame()
dataframe['Region']= regions
dataframe['Total # countries'] = no_of_countries_region
dataframe['# countries having per capita income > $10,000 '] = higher_income_per_region
dataframe['Ratio'] = dataframe['# countries having per capita income > $10,000 '] / dataframe['Total # countries']
dataframe
# Out:
#           Region  Total # countries  \
# 0         AFRICA                 50
# 1           ASIA                 37
# 2         EUROPE                 44
# 3  NORTH AMERICA                 20
# 4        OCEANIA                 13
# 5  SOUTH AMERICA                 12
#
#    # countries having per capita income > $10,000      Ratio
# 0                                               10  0.200000
# 1                                               21  0.567568
# 2                                               37  0.840909
# 3                                               13  0.650000
# 4                                                4  0.307692
# 5                                                9  0.750000

# %% [markdown]
# #### Problem 3(d)
#
# **For AC209 Students**: Re-run this analysis in Problem 3 but compute the average income per person for each region, instead of the average of the reported incomes per person across countries in the region. Why are these two different? Hint: use this [data set](https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&gid=0).

# %%
#your code here

# %% [markdown]
# ## Discussion for Problem 3
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---
